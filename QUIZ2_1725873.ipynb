# %% [markdown]
# <a href="https://colab.research.google.com/github/Odai1725873/QUIZ2/blob/main/QUIZ2_1725873.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# the required libraries
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
# To read the image:
image = cv2.imread('lego1.png')

# To convert the image to grayscale:
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
# To plot the grayscale image:
plt.figure()
plt.imshow(gray, cmap='gray')
plt.title('Grayscale image')
# Out:
# Text(0.5, 1.0, 'Grayscale image')

# %%
#  To convert the image into a black and white (two-color) image (Binarize the image):
_, binary = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)

# %%
# To plot the binary image:
plt.imshow(binary, cmap='gray')
plt.title('Binary image')
plt.show()

# %%
# to preform the morphological operations to remove noise:
kernel = np.ones((3,3), np.uint8)
opening = cv2.morphologyEx(binary, cv2.MORPH_OPEN, kernel, iterations=2)

# %%
# To plot the image after morphological opening:
plt.imshow(opening, cmap='gray')
plt.title('Image after morphological opening')
plt.show()

# %%
# To preform morphological closing to fill in small holes:
closing = cv2.morphologyEx(opening, cv2.MORPH_CLOSE, kernel, iterations=3)

# %%
# To preform the image after morphological closing:
plt.imshow(closing, cmap='gray')
plt.title('Image after morphological closing')
plt.show()

# %%
# To erode away small circles inside the objects:
erosion = cv2.erode(closing, kernel, iterations=3)

# %%
# To plot the image after erosion:
plt.imshow(erosion, cmap='gray')
plt.title('Image after erosion')
plt.show()

# %%
# To preform edge detection:
edges = cv2.Canny(erosion, 50, 100)

# %%
# To plot the edges:
plt.imshow(edges, cmap='gray')
plt.title('Edges')
plt.show()

# %%
# To find the contours of the edges:
contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
# To plot the contours on the original image:
image_contours = cv2.drawContours(image, contours, -1, (0,0,255), 2)
plt.imshow(image_contours)
plt.title('Contours on original image')
plt.show()

# %%
# To print the number of objects in the image:
print(f'Number of objects in the image: {len(contours)}')
# Out:
# Number of objects in the image: 20

# %%
""" 
To simplify the image and reduce the number of color channels, the image is read and converted to grayscale.

To convert the image into a black and white (two-color) image, the grayscale image is binarized using a threshold value.

Morphological opening is applied to the binary image, to remove small noise and details from the image.

Morphological closing is applied to the image after morphological opening, to fill in small holes in the objects.

Erosion is applied to the image after morphological closing, to erode away small circles inside the objects.

The edges of the objects are detected using the Canny edge detector.

The contours of the edges are found using the cv2.findContours() function.

The number of contours is counted, and this is the number of objects in the image.
"""
# Out:
# ' \nTo simplify the image and reduce the number of color channels, the image is read and converted to grayscale.\n\nTo convert the image into a black and white (two-color) image, the grayscale image is binarized using a threshold value.\n\nMorphological opening is applied to the binary image, to remove small noise and details from the image.\n\nMorphological closing is applied to the image after morphological opening, to fill in small holes in the objects.\n\nErosion is applied to the image after morphological closing, to erode away small circles inside the objects.\n\nThe edges of the objects are detected using the Canny edge detector.\n\nThe contours of the edges are found using the cv2.findContours() function.\n\nThe number of contours is counted, and this is the number of objects in the image.\n'
